# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns',200)
df =pd.read_csv('C:/Users/MT/Desktop/globalterrorismdb_0718dist.csv', encoding='latin1')
# Out:
# C:\Users\MT\AppData\Local\Temp\ipykernel_19188\1609438827.py:7: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv('C:/Users/MT/Desktop/globalterrorismdb_0718dist.csv', encoding='latin1')

# %%
df
# Out:
#              eventid      iyear   imonth     iday approxdate  extended  \
# 0       1.970000e+11       1970        7        2        NaN         0
# 1       1.970000e+11       1970        0        0        NaN         0
# 2       1.970000e+11       1970        1        0        NaN         0
# 3       1.970000e+11       1970        1        0        NaN         0
# 4       1.970000e+11       1970        1        0        NaN         0
# ...              ...        ...      ...      ...        ...       ...
# 181688  2.020000e+11       2017       12       31        NaN         0
# 181689  2.020000e+11       2017       12       31        NaN         0
# 181690  2.020000e+11       2017       12       31        NaN         0
# 181691  3.640000e+16  363861482  1175046  2817236  361119086      8239
# 181692  7.280000e+16  727722964  2350092  5634472  722238172     16478
#
#          resolution   country         country_txt   region  \
# ...

# %%
def unistats(df):
    
    output_df= pd.DataFrame(columns=['Count','Missing','Unique','DType','Numeric','Mode','Mean','Min','25%','Median','75%','Max','std','skew','kurt'])
    for col in df:
        if pd.api.types.is_numeric_dtype(df[col]):
            output_df.loc[col] =[df[col].count(),df[col].isnull().sum(),df[col].nunique(),df[col].dtype,pd.api.types.is_numeric_dtype(df[col]), df[col].mode().values[0],df[col].mean(),df[col].min(),df[col].quantile(0.25),df[col].median(),df[col].quantile(0.75),df[col].max(),df[col].std(),df[col].skew(),df[col].kurt()] 
        else: 
            output_df.loc[col] =[df[col].count(),df[col].isnull().sum(),df[col].nunique(),df[col].dtype,pd.api.types.is_numeric_dtype(df[col]), df[col].mode().values[0],'','','','','','','','','']
    
    return output_df
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',100)
df =pd.read_csv('C:/Users/MT/Desktop/globalterrorismdb_0718dist.csv', encoding='latin1')
unistats(df)
# Out:
# C:\Users\MT\AppData\Local\Temp\ipykernel_19188\192541136.py:13: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv('C:/Users/MT/Desktop/globalterrorismdb_0718dist.csv', encoding='latin1')
#              Count  Missing  Unique    DType  Numeric  \
# eventid     181693        0       8  float64     True
# iyear       181693        0      49    int64     True
# imonth      181693        0      15    int64     True
# iday        181693        0      34    int64     True
# approxdate    9241   172452    2246   object    False
# ...            ...      ...     ...      ...      ...
# INT_LOG     181693        0       5    int64     True
# INT_IDEO    181693        0       5    int64     True
# INT_MISC    181693        0       5    int64     True
# INT_ANY     181693        0       5    int64     True
# related      25040   156653   14307   object    False
#
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970000e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970000e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970000e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.shape
# Out:
# (181693, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday       extended  \
# count  1.816930e+05  1.816930e+05  1.816930e+05  1.816930e+05  181693.000000
# mean   8.013354e+11  8.010468e+03  2.586882e+01  6.202189e+01       0.181383
# std    1.909479e+14  1.908752e+06  6.164083e+03  1.477872e+04      43.220825
# min    1.970000e+11  1.970000e+03  0.000000e+00  0.000000e+00       0.000000
# 25%    1.990000e+11  1.991000e+03  4.000000e+00  8.000000e+00       0.000000
# 50%    2.010000e+11  2.009000e+03  6.000000e+00  1.500000e+01       0.000000
# 75%    2.010000e+11  2.014000e+03  9.000000e+00  2.300000e+01       0.000000
# max    7.280000e+16  7.277230e+08  2.350092e+06  5.634472e+06   16478.000000
#
#             country        region      latitude     longitude    specificity  \
# count  1.816930e+05  1.816930e+05  1.771370e+05  1.771360e+05  181687.000000
# mean   5.278682e+02  2.864344e+01  9.399231e+01 -1.834762e+03       5.805743
# ...

# %% [markdown]
# # Data preparation

# %%
df.drop(['attacktype2_txt','attacktype3','attacktype3_txt','targtype2','targtype2_txt','targsubtype2','targsubtype2_txt','corp2','target2','natlty2','natlty2_txt','targtype3','targtype3_txt','targsubtype3','targsubtype3_txt','corp3','target3','natlty3','natlty3_txt'],axis=1,inplace=True)

# %%
df.drop(['gsubname','gname2','gsubname2','gname3','gsubname3','guncertain2','guncertain3','claim2','claimmode2','claimmode2_txt','claim3','claimmode3','claimmode3_txt','compclaim','weaptype2','weaptype2_txt','weapsubtype2','weapsubtype2_txt','weaptype3'],axis=1,inplace=True)

# %%
df.drop(['weaptype3_txt','weapsubtype3','weapsubtype3_txt','weaptype4','weaptype4_txt','weapsubtype4','weapsubtype4_txt'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'alternative_txt', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'attacktype2', 'targtype1',
#        'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1',
#        'natlty1', 'natlty1_txt', 'gname', 'motive', 'guncertain1',
#        'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode',
#        'claimmode_txt', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid',
# ...

# %%
df.shape
# Out:
# (181693, 90)

# %%
df.isna().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# targtype1                  0
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'alternative_txt', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'attacktype2', 'targtype1',
#        'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1',
#        'natlty1', 'natlty1_txt', 'gname', 'motive', 'guncertain1',
#        'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode',
#        'claimmode_txt', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid',
# ...

# %%
df['targsubtype1_txt'].unique()
# Out:
# array(['Named Civilian',
#        'Diplomatic Personnel (outside of embassy, consulate)',
#        'Radio Journalist/Staff/Facility', 'Embassy/Consulate',
#        'Police Building (headquarters, station, school)',
#        'Police Security Forces/Officers', 'Electricity',
#        'Military Recruiting Station/Academy',
#        'Government Building/Facility/Office',
#        'Military Barracks/Base/Headquarters/Checkpost',
#        'Aircraft (not at an airport)', 'Retail/Grocery/Bakery', nan,
#        'Military Personnel (soldiers, troops, officers, forces)',
#        'School/University/Educational Building',
#        'Multinational Corporation', 'Party Office/Facility',
#        'House/Apartment/Residence', 'Race/Ethnicity Identified',
#        'Judge/Attorney/Court',
#        'Police Patrol (including vehicles and convoys)',
#        'Place of Worship', 'Vehicles/Transportation',
#        'Bus (excluding tourists)',
#        'Politician or Political Party Movement/Meeting/Rally',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181693 entries, 0 to 181692
# Data columns (total 90 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   eventid             181693 non-null  float64
#  1   iyear               181693 non-null  int64
#  2   imonth              181693 non-null  int64
#  3   iday                181693 non-null  int64
#  4   approxdate          9241 non-null    object
#  5   extended            181693 non-null  int64
#  6   resolution          2222 non-null    object
#  7   country             181693 non-null  int64
#  8   country_txt         181693 non-null  object
#  9   region              181693 non-null  int64
#  10  region_txt          181693 non-null  object
#  11  provstate           181272 non-null  object
#  12  city                181259 non-null  object
#  13  latitude            177137 non-null  float64
#  14  longitude           177136 non-null  float64
# ...

# %%
df['attacktype2'].unique()
# Out:
# array([       nan, 2.0000e+00, 7.0000e+00, 3.0000e+00, 6.0000e+00,
#        1.0000e+00, 4.0000e+00, 5.0000e+00, 9.0000e+00, 8.0000e+00,
#        2.3485e+04, 4.6970e+04])

# %%
df['guncertain1'].unique()
# Out:
# array([0.0000e+00, 1.0000e+00,        nan, 1.4766e+04, 2.9532e+04])

# %%
df['individual'].unique()
# Out:
# array([   0,    1,  536, 1072], dtype=int64)

# %%
df2=df[['country','country_txt','region','region_txt','alternative','alternative_txt','attacktype1','attacktype1_txt','targtype1','targtype1_txt','targsubtype1','targsubtype1_txt','natlty1','natlty1_txt','claimmode','claimmode_txt','weaptype1','weaptype1_txt','weapsubtype1','weapsubtype1_txt','propextent','propextent_txt','hostkidoutcome','hostkidoutcome_txt']]

# %%
df2
# Out:
#          country         country_txt   region                   region_txt  \
# 0             58  Dominican Republic        2  Central America & Caribbean
# 1            130              Mexico        1                North America
# 2            160         Philippines        5               Southeast Asia
# 3             78              Greece        8               Western Europe
# 4            101               Japan        4                    East Asia
# ...          ...                 ...      ...                          ...
# 181688       160         Philippines        5               Southeast Asia
# 181689        92               India        6                   South Asia
# 181690       160         Philippines        5               Southeast Asia
# 181691  23977489                   0  1301078                            0
# 181692  47954978                   0  2602156                            0
#
#         alternative alternative_txt  attacktype1  \
# ...

# %%
df
# Out:
#              eventid      iyear   imonth     iday approxdate  extended  \
# 0       1.970000e+11       1970        7        2        NaN         0
# 1       1.970000e+11       1970        0        0        NaN         0
# 2       1.970000e+11       1970        1        0        NaN         0
# 3       1.970000e+11       1970        1        0        NaN         0
# 4       1.970000e+11       1970        1        0        NaN         0
# ...              ...        ...      ...      ...        ...       ...
# 181688  2.020000e+11       2017       12       31        NaN         0
# 181689  2.020000e+11       2017       12       31        NaN         0
# 181690  2.020000e+11       2017       12       31        NaN         0
# 181691  3.640000e+16  363861482  1175046  2817236  361119086      8239
# 181692  7.280000e+16  727722964  2350092  5634472  722238172     16478
#
#          resolution   country         country_txt   region  \
# ...

# %%
df.drop(['attacktype2','country','region','alternative','attacktype1','targtype1','targsubtype1','natlty1','claimmode','weaptype1','weapsubtype1','propextent','hostkidoutcome'],axis=1,inplace=True)

# %%
df.loc[df.duplicated()]
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 68      1.970000e+11   1970       2    16        NaN         0        NaN
# 88      1.970000e+11   1970       2    23        NaN         0        NaN
# 89      1.970000e+11   1970       2    23        NaN         0        NaN
# 90      1.970000e+11   1970       2    23        NaN         0        NaN
# 337     1.970000e+11   1970       6     9        NaN         1  6/12/1970
# ...              ...    ...     ...   ...        ...       ...        ...
# 181270  2.020000e+11   2017      12    12        NaN         0        NaN
# 181321  2.020000e+11   2017      12    15        NaN         0        NaN
# 181397  2.020000e+11   2017      12    18        NaN         0        NaN
# 181634  2.020000e+11   2017      12    29        NaN         0        NaN
# 181657  2.020000e+11   2017      12    30        NaN         0        NaN
#
#           country_txt                  region_txt        provstate  \
# ...

# %%
df.query('eventid == 197000000000')
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0     1.970000e+11   1970       7     2        NaN         0        NaN
# 1     1.970000e+11   1970       0     0        NaN         0        NaN
# 2     1.970000e+11   1970       1     0        NaN         0        NaN
# 3     1.970000e+11   1970       1     0        NaN         0        NaN
# 4     1.970000e+11   1970       1     0        NaN         0        NaN
# ...            ...    ...     ...   ...        ...       ...        ...
# 2739  1.970000e+11   1974      12    31        NaN         0        NaN
# 2740  1.970000e+11   1974      12    31        NaN         0        NaN
# 2741  1.970000e+11   1974      12    31        NaN         0        NaN
# 2742  1.970000e+11   1974      12    31        NaN         0        NaN
# 2743  1.970000e+11   1974      12    31        NaN         0        NaN
#
#              country_txt                   region_txt    provstate  \
# ...

# %%
df=df.loc[~df.duplicated(subset=['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
       'resolution', 'country_txt', 'region_txt', 'provstate', 'city',
       'latitude', 'longitude', 'specificity', 'vicinity', 'location',
       'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative_txt',
       'multiple', 'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
       'targsubtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'gname',
       'motive', 'guncertain1', 'individual', 'nperps', 'nperpcap', 'claimed',
       'claimmode_txt', 'weaptype1_txt', 'weapsubtype1_txt', 'weapdetail',
       'nkill', 'nkillus', 'nkillter', 'nwound', 'nwoundus', 'nwoundte',
       'property', 'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
       'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry',
       'ransom', 'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus',
       'ransomnote', 'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1',
       'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC',
       'INT_ANY', 'related'])] \
       .reset_index(drop=True).copy()

# %%
df['attacktype1_txt']
# Out:
# 0                          Assassination
# 1            Hostage Taking (Kidnapping)
# 2                          Assassination
# 3                      Bombing/Explosion
# 4         Facility/Infrastructure Attack
#                        ...
# 177128    Facility/Infrastructure Attack
# 177129                 Bombing/Explosion
# 177130                 Bombing/Explosion
# 177131                                 0
# 177132                                 0
# Name: attacktype1_txt, Length: 177133, dtype: object

# %%
df.shape
# Out:
# (177133, 77)

# %%
df['motive'].unique()
# Out:
# array([nan, 'To protest the Cairo Illinois Police Deparment',
#        'To protest the War in Vietnam and the draft', ...,
#        'The specific motive is unknown; however, sources noted that the targeted building housed migrants.',
#        'The specific motive is unknown; however, sources stated that the Taliban had warned one of the victims against collaborating with the government.',
#        '0'], dtype=object)

# %%
#univariate analysis
plt.figure(figsize=(18,8))
a=df['iyear'].value_counts()\
  .plot(kind='bar',title='Most year crime committed on ')
a.set_xlabel('year')
a.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
b=df['weaptype1_txt'].value_counts()\
  .plot(kind='bar',title='which weapon used more')
b.set_xlabel('weapon')
b.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df.to_csv('terrorism.csv')
